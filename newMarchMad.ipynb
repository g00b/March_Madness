# %%
# Get the data source and prepare a dataframe

import pandas as pd
import numpy as np

data = pd.read_csv("./Dataset/MarchmadnessDatasetFull.csv", header="infer")
# display(data.head(10))

data2 = pd.read_csv("./Dataset/RegularSeasonDetailedResults.csv", header="infer")
display(data2.head(10))

teams = pd.read_csv("./Dataset/Teams.csv", header="infer")
# teams.head(10)
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
# 5    2003      11     1458      81     1186      55    H      0    26    57
# 6    2003      12     1161      80     1236      62    H      0    23    55
# 7    2003      12     1186      75     1457      61    N      0    28    62
# 8    2003      12     1194      71     1156      66    N      0    28    58
# 9    2003      12     1458      84     1296      56    H      0    32    67
#
#   ...   LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0 ...      10    16    22   10   22     8   18     9     2   20
# 1 ...      24     9    20   20   25     7   12     8     6   16
# 2 ...      26    14    23   31   22     9   12     2     5   23
# 3 ...      22     8    15   17   20     9   19     4     3   23
# 4 ...      16    17    27   21   15    12   10     7     1   14
# 5 ...      11    12    17    6   22     8   19     4     3   25
# 6 ...      15    20    28    9   21    11   30    10     4   28
# 7 ...      17    17    23    8   25    10   15    14     8   18
# 8 ...      18    12    27   13   26    13   25     8     2   18
# 9 ...      14     7    12    9   23    10   18     1     3   18
#
# [10 rows x 34 columns]

# %%
# Preprocess Dataset

# Drop the Location, Rk and Region info because it's irrelevant
#data2 = data2.drop('DayNum', axis=1)#not important for analysis
data2 = data2.drop('WLoc', axis=1)#not important for analysis
# data2 = data2.drop('WTeamID', axis=1)#not important for analysis
# data2 = data2.drop('LTeamID', axis=1)#not important for analysis
# data2 = data2.drop('Season', axis=1)#not important for analysis

data = data.drop('Rk', axis=1)#not important for analysis
data = data.drop('Year', axis=1)#not important for analysis
data = data.drop('Date', axis=1)#not important for analysis
data = data.drop('Location', axis=1)#not important for analysis
data = data.drop('Region', axis=1)#not important for analysis

data2 = data2.drop('WPF', axis=1) #Personal Fouls are not significant
data2 = data2.drop('LPF', axis=1)

# %%
#Store the teams into a dictionary of dictionarys Dict['Team']['Stat'] = [List Total Stats]

real_teams = ['Alabama', 'Arizona','Arizona St', 'Arkansas', 'Auburn','Bucknell','Buffalo','Butler','CS Fullerton',
'Charleston','Cincinnati', 'Clemson','Creighton', 'Davidson','Duke','Florida','Florida St','Georgia St', 'Gonzaga',
'Houston','Iona','Kansas', 'Kansas State', 'Kentucky','Lipscomb', 'Long Island', 'Loyola-Chicago', 'Marshall',
'Miami FL','Michigan','Michigan St', 'Missouri','Montana','Murray St', 
'Nevada','New Mexico St','NC Central', 'NC State','North Carolina','Ohio St','Oklahoma',
'Penn','Providence', 'Purdue','Radford', 'Rhode Island', 'San Diego St', 'Seton Hall','S Dakota St','St Bonaventure',
'SF Austin','Syracuse','TCU','Tennessee','Texas','Texas A&M', 'TX Southern','Texas Tech','UCLA','UMBC', 
'UNC Greensboro', 'Villanova','Virginia','Virginia Tech', 'West Virginia','Wichita St' ,'Wright St','Xavier'] 

seasons = [2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017]

###Average the data we want per Season By Team




display(data2.head(5))
#teams = teams[teams['TeamName'].isin(real_teams)]
# print((teams))
print(type(teams))
#Now we have current season teams
print(len(data2))
##Create dictionaries for the season data for teams to average
team_dict = dict()
team_dict[2003] = {}
team_dict[2004] = {}
team_dict[2005] = {}
team_dict[2006] = {}
team_dict[2007] = {}
team_dict[2008] = {}
team_dict[2009] = {}
team_dict[2010] = {}
team_dict[2011] = {}
team_dict[2012] = {}
team_dict[2013] = {}
team_dict[2014] = {}
team_dict[2015] = {}
team_dict[2016] = {}
team_dict[2017] = {}




for eachT in seasons:
    for eachTeam in real_teams:
        team_dict[eachT][eachTeam] = []
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore  NumOT  WFGM  WFGA  WFGM3  \
# 0    2003      10     1104      68     1328      62      0    27    58      3
# 1    2003      10     1272      70     1393      63      0    26    62      8
# 2    2003      11     1266      73     1437      61      0    24    58      8
# 3    2003      11     1296      56     1457      50      0    18    38      3
# 4    2003      11     1400      77     1208      71      0    30    61      6
#
#    ...   LFGM3  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk
# 0  ...       2     10    16    22   10   22     8   18     9     2
# 1  ...       6     24     9    20   20   25     7   12     8     6
# 2  ...       3     26    14    23   31   22     9   12     2     5
# 3  ...       6     22     8    15   17   20     9   19     4     3
# 4  ...       6     16    17    27   21   15    12   10     7     1
#
# [5 rows x 31 columns]
# <class 'pandas.core.frame.DataFrame'>
# 76636

# %%
#teams = teams[teams['TeamName'].isin(real_teams)]

for index, team in teams.iterrows():
    #print(team.TeamID)
    team_dict_list = []
    team_ft_list = []
    team_fgp_list = []
    for index, row2 in data2.iterrows():
        if(row2.WTeamID == team.TeamID):
            game_stats_list = [row2.WScore ]
            team_dict[row2.Season][team.TeamName].append(game_stats_list)
            #print(row2.WScore)
            #team_dict_list.append(row2.WScore)
            #team_ft_list.append('%.3f' % round(row2.WScore))
            #team_fgp_list.append('%.3f' % round(row2.WScore))
            #print('birdup')
        elif(row2.LTeamID == team.TeamID):
            game_stats_list2 = [row2.LScore ]
            team_dict[row2.Season][team.TeamName].append(game_stats_list2)
            #team_dict_list.append(row2.LScore - row2.WScore)
            #team_ft_list.append('%.3f' % round(row2.LFTP,3))
            #team_fgp_list.append('%.3f' % round(row2.LFGP,3))
            #print(row2.WScore)
    #team_dict[team.TeamName] = {}
    #team_dict[team.TeamName]['team_points'] = team_dict_list
    #team_dict[team.TeamName]['team_ft_list'] = team_ft_list
    #team_dict[team.TeamName]['team_fgp_list'] = team_fgp_list
    print("we out here")
print(team_dict)
# Out:
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# we out here
# {2003: {'Alabama': [[68], [82], [80], [54], [89], [77], [72], [69], [82], [49], [65], [61], [69], [68], [68], [57], [46], [75], [70], [56], [84], [69], [76], [55], [86], [82], [62], [69], [68], [82], [80], [54], [89], [77], [72], [69], [82], [49], [65], [61], [69], [68], [68], [57], [46], [75], [70], [56], [84], [69], [76], [55], [86], [82], [62], [69]], 'Arizona': [[107], [101], [91], [89], [73], [65], [95], [85], [81], [80], [82], [79], [81], [87], [71], [91], [77], [95], [88], [75], [106], [86], [92], [88], [72], [72], [88], [89], [107], [101], [91], [89], [73], [65], [95], [85], [81], [80], [82], [79], [81], [87], [71], [91], [77], [95], [88], [75], [106], [86], [92], [88], [72], [72], [88], [89]], 'Arizona St': [[59], [65], [83], [85], [60], [55], [76], [70], [79], [75], [67], [73], [89], [96], [75], [74], [63], [75], [57], [87], [79], [108], [85], [72], [77], [72], [91], [74], [82], [59], [65], [83], [85], [60], [55], [76], [70], [79], [75], [67], [73], [89], [96], [75], [
# %%
#####Now that the data is preprocessed appropriately we will need to  start taking the averages of the data for the model
from statistics import mean

### Averages
for key, value in team_dict.items():
    print(key)
    for k2,v2 in value.items():
        #print(k2, v2)
        #print(k2,*map(mean, zip(*v2)))
        v2 = [(*map(mean, zip(*v2)))]
        team_dict[key][k2]= v2
        #print(k2, v2)

print(team_dict)

###Dictionary is now much more managable and  averages are now here
# Out:
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# {2003: {'Alabama': [69], 'Arizona': [85], 'Arizona St': [75], 'Arkansas': [61], 'Auburn': [70], 'Bucknell': [57], 'Buffalo': [64], 'Butler': [68], 'CS Fullerton': [62], 'Charleston': [], 'Cincinnati': [67], 'Clemson': [68], 'Creighton': [79], 'Davidson': [76], 'Duke': [81], 'Florida': [75], 'Florida St': [68], 'Georgia St': [73], 'Gonzaga': [77], 'Houston': [58], 'Iona': [74], 'Kansas': [81], 'Kansas State': [], 'Kentucky': [77], 'Lipscomb': [76], 'Long Island': [75], 'Loyola-Chicago': [74], 'Marshall': [71], 'Miami FL': [69], 'Michigan': [69], 'Michigan St': [67], 'Missouri': [71], 'Montana': [69], 'Murray St': [74], 'Nevada': [76], 'New Mexico St': [73], 'NC Central': [], 'NC State': [72], 'North Carolina': [71], 'Ohio St': [64], 'Oklahoma': [71], 'Penn': [70], 'Providence': [72], 'Purdue': [71], 'Radford': [63], 'Rhode Island': [70], 'San Diego St': [71], 'Seton Hall': [67], 'S Dakota St': [], 'St Bonaventure': [79], 'SF Austin': [70], 'Syracuse': [80], 'TCU': [76], 'Tennessee': [68], 'Texas': [78], 'Texas A&M': [71], 'TX Southern': [72], 'Texas Tech': [73], 'UCLA': [75], 'UMBC': [63], 'UNC Greensboro': [69], 'Villanova': [72], 'Virginia': [73], 'Virginia Tech': [70], 'West Virginia': [66], 'Wichita St': [72], 'Wright St': [67], 'Xavier': [78]}, 2004: {'Alabama': [72], 'Arizona': [87], 'Arizona St': [74], 'Arkansas': [68], 'Auburn': [70], 'Bucknell': [63], 'Buffalo': [75], 'Butler': [62], 'CS Fullerton': [70], 'Charleston': [], 'Cincinnati': [76], 'Clemson': [65], 'Creighton': [68], 'Davidson': [70], 'Duke': [79], 'Florida': [76], 'Florida St': [70], 'Georgia St': [73], 'Gonzaga': [82], 'Houston': [58], 'Iona': [71], 'Kansas': [74], 'Kansas State': [], 'Kentucky': [73], 'Lipscomb': [68], 'Long Island': [69], 'Loyola-Chicago': [70], 'Marshall': [69], 'Miami FL': [71], 'Michigan': [68], 'Michigan St': [71], 'Missouri': [74], 'Montana': [68], 'Murray St': [80], 'Nevada': [75], 'New Mexico St': [64], 'NC Central': [], 'NC State': [73], 'North Carolina': [83], 'Ohio St': [65], 'Oklahoma': [66], 'Penn': [71], 'Providence': [71], 'Purdue': [65], 'Radford': [66], 'Rhode Island': [68], 'San Diego St': [70], 'Seton Hall': [72], 'S Dakota St': [], 'St Bonaventure': [68], 'SF Austin': [68], 'Syracuse': [72], 'TCU': [66], 'Tennessee': [71], 'Texas': [77], 'Texas A&M': [71], 'TX Southern': [65], 'Texas Tech': [73], 'UCLA': [66], 'UMBC': [60], 'UNC Greensboro': [73], 'Villanova': [69], 'Virginia': [74], 'Virginia Tech': [66], 'West Virginia': [65], 'Wichita St': [70], 'Wright St': [66], 'Xavier': [70]}, 2005: {'Alabama': [75], 'Arizona': [79], 'Arizona St': [75], 'Arkansas': [71], 'Auburn': [70], 'Bucknell': [63], 'Buffalo': [75], 'Butler': [63], 'CS Fullerton': [74], 'Charleston': [], 'Cincinnati': [76], 'Clemson': [71], 'Creighton': [71], 'Davidson': [70], 'Duke': [79], 'Florida': [76], 'Florida St': [68], 'Georgia St': [70], 'Gonzaga': [79], 'Houston': [69], 'Iona': [71], 'Kansas': [75], 'Kansas State': [], 'Kentucky': [73], 'Lipscomb': [67], 'Long Island': [67], 'Loyola-Chicago': [67], 'Marshall': [66], 'Miami FL': [71], 'Michigan': [61], 'Michigan St': [78], 'Missouri': [64], 'Montana': [69], 'Murray St': [70], 'Nevada': [69], 'New Mexico St': [66], 'NC Central': [], 'NC State': [73], 'North Carolina': [88], 'Ohio St': [71], 'Oklahoma': [75], 'Penn': [68], 'Providence': [74], 'Purdue': [62], 'Radford': [67], 'Rhode Island': [57], 'San Diego St': [68], 'Seton Hall': [62], 'S Dakota St': [], 'St Bonaventure': [61], 'SF Austin': [61], 'Syracuse': [75], 'TCU': [70], 'Tennessee': [68], 'Texas': [77], 'Texas A&M': [73], 'TX Southern': [65], 'Texas Tech': [77], 'UCLA': [74], 'UMBC': [60], 'UNC Greensboro': [69], 'Villanova': [73], 'Virginia': [72], 'Virginia Tech': [69], 'West Virginia': [70], 'Wichita St': [71], 'Wright St': [63], 'Xavier': [70]}, 2006: {'Alabama': [69], 'Arizona': [72], 'Arizona St': [67], 'Arkansas': [74], 'Auburn': [65], 'Bucknell': [66], 'Buffalo': [71], 'Butler': [68], 'CS Fullerton': [78], 'Charleston': [], 'Cincinna ...

# %%
##Now we begin creating all the differences between team data for our prediction model data
### WE need to iterate over the original data of the games again to now build the difference between our two team vectors

###Also just realizing it makes sense to convert the TeamID's to names since that's the key value

#print(teams)
for index, team in teams.iterrows():
    for index2, row2 in data2.iterrows():
        if(row2.WTeamID == team.TeamID):
            print(index2)
            print(team.TeamName)
            newD = pd.DataFrame({'WTeamID': [team.TeamName]}, index=[index2])
            data2.update(newD)
    display(data2.head(5))
    print('birdup')
# Out:
# 0
# Alabama
# 34
# Alabama
# 207
# Alabama
# 340
# Alabama
# 518
# Alabama
# 650
# Alabama
# 854
# Alabama
# 1094
# Alabama
# 1216
# Alabama
# 1582
# Alabama
# 1768
# Alabama
# 2080
# Alabama
# 2789
# Alabama
# 3420
# Alabama
# 3723
# Alabama
# 4171
# Alabama
# 4231
# Alabama
# 4658
# Alabama
# 4847
# Alabama
# 5145
# Alabama
# 5242
# Alabama
# 5573
# Alabama
# 5659
# Alabama
# 5876
# Alabama
# 6002
# Alabama
# 6624
# Cincinnati
# 11562
# Cincinnati
# 11929
# Cincinnati
# 11992
# Cincinnati
# 12562
# Cincinnati
# 12835
# Cincinnati
# 12962
# Cincinnati
# 13210
# Cincinnati
# 13273
# Cincinnati
# 13468
# Cincinnati
# 13587
# Cincinnati
# 14011
# Cincinnati
# 14144
# Cincinnati
# 14232
# Cincinnati
# 14824
# Cincinnati
# 14963
# Cincinnati
# 15005
# Cincinnati
# 15238
# Cincinnati
# 15295
# Cincinnati
# 15352
# Cincinnati
# 15452
# Cincinnati
# 15663
# Cincinnati
# 15788
# Cincinnati
# 16547
# Cincinnati
# 16930
# Cincinnati
# 17212
# Cincinnati
# 17588
# Cincinnati
# 17687
# Cincinnati
# 18352
# Cincinnati
# 18638
# Cincinnati
# 18701
# Cincinnati
# 18756
# Cincinnati
# 19284
# Cincinnati
# 19467
# Cincinnati
# 19850
# Cincinnati
# 19982
# Cincinnati
# 20341
# Cincinnati
# 20389
# Cincinnati
# 21452
# Cincinnati
# 23255
# Cincinnati
# 23750
# Cincinnati
# 23973
# Cincinnati
# 24319
# Cincinnati
# 24431
# Cincinnati
# 25480
# Cincinnati
# 25624
# Cincinnati
# 25928
# Cincinnati
# 26051
# Cincinnati
# 26356
# Cincinnati
# 26856
# Cincinnati
# 27295
# Cincinnati
# 27489
# Cincinnati
# 27815
# Cincinnati
# 28963
# Cincinnati
# 29053
# Cincinnati
# 29227
# Cincinnati
# 29338
# Cincinnati
# 29565
# Cincinnati
# 29877
# Cincinnati
# 30210
# Cincinnati
# 30290
# Cincinnati
# 30343
# Cincinnati
# 30462
# Cincinnati
# 31353
# Cincinnati
# 31490
# Cincinnati
# 31744
# Cincinnati
# 32006
# Cincinnati
# 32337
# Cincinnati
# 32470
# Cincinnati
# 32672
# Cincinnati
# 33384
# Cincinnati
# 34273
# Cincinnati
# 34370
# Cincinnati
# 34607
# Cincinnati
# 34652
# Cincinnati
# 34989
# Cincinnati
# 35357
# Cincinnati
# 35589
# Cincinnati
# 35754
# Cincinnati
# 35997
# Cincinnati
# 36095
# Cincinnati
# 36301
# Cincinnati
# 36758
# Cincinnati
# 36951
# Cincinnati
# 37423
# Cincinnati
# 38073
# Cincinnati
# 38591
# Cincinnati
# 39182
# Cincinnati
# 39199
# Cincinnati
# 39523
# Cincinnati
# 39757
# Cincinnati
# 39871
# Cincinnati
# 39985
# Cincinnati
# 40097
# Cincinnati
# 40280
# Cincinnati
# 40396
# Cincinnati
# 40656
# Cincinnati
# 40790
# Cincinnati
# 40862
# Cincinnati
# 41010
# Cincinnati
# 41145
# Cincinnati
# 41205
# Cincinnati
# 41359
# Cincinnati
# 41591
# Cincinnati
# 41853
# Cincinnati
# 42318
# Cincinnati
# 42514
# Cincinnati
# 43152
# Cincinnati
# 43514
# Cincinnati
# 43635
# Cincinnati
# 43828
# Cincinnati
# 44155
# Cincinnati
# 44284
# Cincinnati
# 44438
# Cincinnati
# 44725
# Cincinnati
# 44821
# Cincinnati
# 45117
# Cincinnati
# 45489
# Cincinnati
# 45615
# Cincinnati
# 46046
# Cincinnati
# 46094
# Cincinnati
# 46303
# Cincinnati
# 46434
# Cincinnati
# 46533
# Cincinnati
# 46708
# Cincinnati
# 46800
# Cincinnati
# 47079
# Cincinnati
# 47267
# Cincinnati
# 47456
# Cincinnati
# 48236
# Cincinnati
# 48432
# Cincinnati
# 48771
# Cincinnati
# 48893
# Cincinnati
# 49142
# Cincinnati
# 49414
# Cincinnati
# 49542
# Cincinnati
# 49731
# Cincinnati
# 49776
# Cincinnati
# 49967
# Cincinnati
# 50044
# Cincinnati
# 50286
# Cincinnati
# 50383
# Cincinnati
# 50512
# Cincinnati
# 50567
# Cincinnati
# 50836
# Cincinnati
# 51066
# Cincinnati
# 51102
# Cincinnati
# 51269
# Cincinnati
# 51436
# Cincinnati
# 51553
# Cincinnati
# 51821
# Cincinnati
# 52323
# Cincinnati
# 52482
# Cincinnati
# 52644
# Cincinnati
# 53137
# Cincinnati
# 53285
# Cincinnati
# 53765
# Cincinnati
# 54556
# Cincinnati
# 54871
# Cincinnati
# 55013
# Cincinnati
# 55170
# Cincinnati
# 55355
# Cincinnati
# 55520
# Cincinnati
# 55704
# Cincinnati
# 55991
# Cincinnati
# 56105
# Cincinnati
# 56302
# Cincinnati
# 56717
# Cincinnati
# 56848
# Cincinnati
# 56980
# Cincinnati
# 57016
# Cincinnati
# 57185
# Cincinnati
# 57296
# Cincinnati
# 57434
# Cincinnati
# 57598
# Cincinnati
# 57760
# Cincinnati
# 57918
# Cincinnati
# 58168
# Cincinnati
# 58377
# Cincinnati
# 58493
# Cincinnati
# 58713
# Cincinnati
# 58822
# Cincinnati
# 59223
# Cincinnati
# 59418
# Cincinnati
# 60115
# Cincinnati
# 60213
# Cincinnati
# 60392
# Cincinnati
# 60533
# Cincinnati
# 60801
# Cincinnati
# 61016
# Cincinnati
# 61120
# Cincinnati
# 61267
# Cincinnati
# 61463
# Cincinnati
# 62003
# Cincinnati
# 62302
# Cincinnati
# 62439
# Cincinnati
# 62595
# Cincinnati
# 62768
# Cincinnati
# 63249
# Cincinnati
# 63453
# Cincinnati
# 63711
# Cincinnati
# 63829
# Cincinnati
# 64160
# Cincinnati
# 64248
# Cincinnati
# 64901
# Cincinnati
# 65094
# Cincinnati
# 65232
# Cincinnati
# 65424
# Cincinnati
# 65662
# Cincinnati
# 65885
# Cincinnati
# 66019
# Cincinnati
# 66157
# Cincinnati
# 66367
# Cincinnati
# 66456
# Cincinnati
# 66602
# Cincinnati
# 66673
# Cincinnati
# 67063
# Cincinnati
# 67342
# Cincinnati
# 67462
# Cincinnati
# 67939
# Cincinnati
# 68399
# Cincinnati
# 68467
# Cincinnati
# 68849
# Cincinnati
# 69047
# Cincinnati
# 69172
# Cincinnati
# 69504
# Cincinnati
# 69766
# Cincinnati
# 69923
# Cincinnati
# 70264
# Cincinnati
# 70597
# Cincinnati
# 71022
# Cincinnati
# 71255
# Cincinnati
# 71422
# Cincinnati
# 71725
# Clemson
# 25278
# Clemson
# 25481
# Clemson
# 25625
# Clemson
# 26052
# Clemson
# 26203
# Clemson
# 26521
# Clemson
# 26985
# Clemson
# 27228
# Clemson
# 27546
# Clemson
# 27619
# Clemson
# 28105
# Clemson
# 28361
# Clemson
# 28626
# Clemson
# 28766
# Clemson
# 28802
# Clemson
# 28847
# Clemson
# 28922
# Clemson
# 28964
# Clemson
# 29112
# Clemson
# 29228
# Clemson
# 29390
# Clemson
# 29499
# Clemson
# 29720
# Clemson
# 29982
# Clemson
# 30096
# Clemson
# 30228
# Clemson
# 30429
# Clemson
# 30706
# Clemson
# 30862
# Clemson
# 31028
# Clemson
# 31167
# Clemson
# 31934
# Clemson
# 32063
# Clemson
# 32338
# Clemson
# 32650
# Clemson
# 32983
# Clemson
# 33263
# Clemson
# 33632
# Clemson
# 34095
# Clemson
# 34316
# Clemson
# 34439
# Clemson
# 34608
# Clemson
# 34780
# Clemson
# 34924
# Clemson
# 35245
# Clemson
# 35465
# Clemson
# 35522
# Clemson
# 35590
# Clemson
# 35755
# Clemson
# 35933
# Clemson
# 36422
# Clemson
# 36619
# Clemson
# 36760
# Clemson
# 37545
# Clemson
# 37943
# Clemson
# 38075
# Clemson
# 38409
# Clemson
# 38862
# Clemson
# 38894
# Clemson
# 39356
# Clemson
# 39524
# Clemson
# 39697
# Clemson
# 39872
# Clemson
# 40043
# Clemson
# 40843
# Clemson
# 40950
# Clemson
# 41071
# Clemson
# 41191
# Clemson
# 41244
# Clemson
# 41427
# Clemson
# 41675
# Clemson
# 41833
# Clemson
# 42491
# Clemson
# 42653
# Clemson
# 42983
# Clemson
# 43153
# Clemson

# %%
##Create our pandas Diff object

Resulting_Differences = []

for index2, row2 in data2.iterrows():
    difComp1 = team_dict[row2.Season][row2.WTeamID]
    difComp2 = team_dict[row2.Season][row2.LTeamID]
    diff = []
    for x in xrange(0,len(difComp1)):
        diff.append(difComp1[x]-difComp2[x])
    Resulting_Differnces.append(diff)
    


####Convert it back into a Panda Dataframe
##All Cells that have been reworked completely solely by Gabriel Martino
##Here we can begin Training our Model off our data, we do need to make a Y List and an inverse of both as well
X = DataFrame(Resulting_differences, columns=headers)
### y = a list of 1's the length of our dataframe to train the data on. We were then going to try cross validation 
##and see our results

# %%
# data2 = data2.drop('WOR', axis=1)
# data2 = data2.drop('WDR', axis=1)
# data2 = data2.drop('LOR', axis=1)
# data2 = data2.drop('LDR', axis=1)

#
# Further pre-process by appending columns 
#
WFTP = [] #Winning team Free Throw Percentage
WFGP = [] #Winning team Field Goal Percentage
LFTP = [] #Losing team Free Throw Percentage
LFGP = [] #Losing team Field Goal Percentage

# Possession stat formula --  0.96*[(FGA)+(TO)+0.44*(FTA)-(ORB)]
LPoss = []
WPoss = []

# calculate the FG% and FT% and append to dataframe
for index, row in data2.iterrows():
    WFGMade = row['WFGM']
    LFGMade = row['LFGM']
    
    WTurnOver = row['WTO']
    LTurnOver = row['LTO']
    
    WOffRebound = row['WOR']
    LOffRebound = row['LOR']
    
    WFGAttempt = row['WFGA']
    LFGAttempt = row['LFGA']
    
    # calculate percentages
    WFGPercent = (WFGMade/(WFGAttempt+WFGMade))
    LFGPercent = (LFGMade/(LFGAttempt+LFGMade))
    
    
    WFGAttempt = float(WFGAttempt)
    WTurnOver = float(WTurnOver)
    WOffRebound = float(WOffRebound)

    LFGAttempt = float(LFGAttempt)
    LTurnOver = float(LTurnOver)
    LOffRebound = float(LOffRebound)
    
    ##Very important statistic
    WinPoss = (0.96*((WFGAttempt)+(WTurnOver)+0.44*(WFTAttempt)-(WOffRebound)))
    LosPoss = (0.96*((LFGAttempt)+(LTurnOver)+0.44*(LFTAttempt)-(LOffRebound)))
    
    
    # append to list
    WFGP.append(WFGPercent)
    LFGP.append(LFGPercent)
    
    LPoss.append(LosPoss)
    WPoss.append(WinPoss)
    
for index, row in data2.iterrows():
    WFTMade = row['WFTM']
    LFTMade = row['LFTM']
    WFTAttempt = row['WFTA']
    LFTAttempt = row['LFTA']
    WFTPercent = (WFTMade/(WFTAttempt+WFTMade))
    LFTPercent = (LFTMade/(LFTAttempt+LFTMade))
    WFTP.append(WFTPercent)
    LFTP.append(LFTPercent)
    
# Make each list a pandas series 
LfreethrowPercent = pd.Series(LFTP)
WfreethrowPercent = pd.Series(WFTP)

LfieldGoalPercent = pd.Series(LFGP)
WfieldGoalPercent = pd.Series(WFGP)

WinPossession = pd.Series(LPoss)
LosPossession = pd.Series(WPoss)

# append to dataframe as column
#data2['WFTP'] = WfreethrowPercent
#data2['LFTP'] = LfreethrowPercent
#data2['WFGP'] = WfieldGoalPercent
#data2['LFGP'] = LfieldGoalPercent

#data2['LPoss'] = LosPossession
#data2['WPoss'] = WinPossession

data2.head(10)

# %%
print(WinPoss)

# %%
#Remove teams that weren't in LastD1Season as they aren't in the tourney

real_teams = ['Alabama', 'Arizona','Arizona St', 'Arkansas', 'Auburn','Bucknell','Buffalo','Butler','CS Fullerton',
'Charleston','Cincinnati', 'Clemson','Creighton', 'Davidson','Duke','Florida','Florida St','Georgia St', 'Gonzaga',
'Houston','Iona','Kansas', 'Kansas State', 'Kentucky','Lipscomb', 'Long Island', 'Loyola-Chicago', 'Marshall',
'Miami FL','Michigan','Michigan St', 'Missouri','Montana','Murray St', 
'Nevada','New Mexico St','NC Central', 'NC State','North Carolina','Ohio St','Oklahoma',
'Penn','Providence', 'Purdue','Radford', 'Rhode Island', 'San Diego St', 'Seton Hall','S Dakota St','St Bonaventure',
'SF Austin','Syracuse','TCU','Tennessee','Texas','Texas A&M', 'TX Southern','Texas Tech','UCLA','UMBC', 
'UNC Greensboro', 'Villanova','Virginia','Virginia Tech', 'West Virginia','Wichita St' ,'Wright St','Xavier'] 


"""#df = df[~df['date'].isin(a)]
teams = teams[teams['TeamName'].isin(real_teams)]
# print((teams))
print(type(teams))
#Now we have current season teams
print(len(data2))
team_dict = dict()
for index, team in teams.iterrows():
    #print(team.TeamID)
    team_dict_list = []
    team_ft_list = []
    team_fgp_list = []
    for index, row2 in data2.iterrows():
        if(row2.WTeamID == team.TeamID):
            #print(row2.WScore)
            team_dict_list.append(row2.WScore - row2.LScore)
            
            team_ft_list.append('%.3f' % round(row2.WFTP,3))
            team_fgp_list.append('%.3f' % round(row2.WFGP,3))
        elif(row2.LTeamID == team.TeamID):
            team_dict_list.append(row2.LScore - row2.WScore)
            team_ft_list.append('%.3f' % round(row2.LFTP,3))
            team_fgp_list.append('%.3f' % round(row2.LFGP,3))
            #print(row2.WScore)
    team_dict[team.TeamName] = {}
    team_dict[team.TeamName]['team_points'] = team_dict_list
    team_dict[team.TeamName]['team_ft_list'] = team_ft_list
    team_dict[team.TeamName]['team_fgp_list'] = team_fgp_list
"""

# %%
#display(data2.head(10))
data2.shape

winThrow = (data2['WFTP'])
loseThrow = (data2['LFTP'])

print(data2.columns.get_loc("WFGP"))
print(data2.columns.get_loc("LFGP"))



diff = pd.DataFrame((data2.iloc[1:,31].values-data2.iloc[:76635,32].values), 
                            columns=['diff_FTP'], index=data2.iloc[1:,0])

diff['diff_FGP'] = pd.DataFrame((data2.iloc[1:,33].values-data2.iloc[:76635,34].values))


display(diff.head(10))

# %%
import math
Z = diff['diff_FTP']
count = 0
display(Z.head(10))
for a in Z:
    count += 1
    if(a != a):
        a = float(1)
        #print("NAN UH OH")
        #print("count", count)
for a in Z:
    count += 1
    if(a != a):
        #a = float(1)
        #print("NAN UH OH")
        #print("count", count)

# %%
Z = Z.fillna(0)

from numpy.linalg import inv
    
Z2 = diff['diff_FGP']
for nan in Z:
    if(nan == 'NaN'):
        nan = 0

columnNames = ['lag5','lag4','lag3','lag2','lag1']
X = pd.DataFrame(np.column_stack((Z[:-5],Z[1:-4],Z[2:-3],Z[3:-2],Z[4:-1])
                                ),columns = columnNames)
iX = pd.DataFrame(np.column_stack((Z[:-5],Z[1:-4],Z[2:-3],Z[3:-2],Z[4:-1])
                                ),columns = columnNames)

print(X.shape)

### We're going to make the win out comes list
### To test for the negative cases we are inversing the data and denoting the losses with a zero for our model
win_count = 0
win_list = []
lose_list = []
while win_count < 76630:
    win_list.append(1)
    lose_list.append(0)
    win_count+=1

#print(win_count)
#print(win_list)


wins = pd.DataFrame(win_list, columns = ['Win'])
loss =  pd.DataFrame(lose_list, columns = ['Win'])



for index, row in iX.iterrows():
    iX.set_value(index,'lag5',-row[0])

#All training data along with inverse Vector differences for losing game scenarios
trainGames = X.append(iX)
results = wins.append(loss)
display(results.shape)

X = trainGames
y = results


#display(trainGames.shape)
    

#display(wins.head(5))
#print(wins.shape)
#display(X.head(5))
#display(iX.head(5))

# %%
from sklearn.model_selection import train_test_split

np.random.seed(1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.333333)

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Create linear regression object
regr = linear_model.LinearRegression()

# Fit regression model to the training set
regr.fit(X_train, y_train)

# Apply model to the test set
y_pred = regr.predict(X_test)

# Model evaluation
print("Root mean squared error = %.4f" % np.sqrt(mean_squared_error(y_test, y_pred)))
print('R-squared = %.4f' % r2_score(y_test, y_pred))
